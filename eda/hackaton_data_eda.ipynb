# %%
from pathlib import Path

import pandas as pd

DATA_DIR = Path('../data/')

# %%
hackaton_df = pd.read_csv(DATA_DIR / 'hackathon_data' / 'hackathon_train.csv')

# %%
hackaton_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50682 entries, 0 to 50681
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   language    50682 non-null  object
#  1   file        50682 non-null  object
#  2   speaker     50682 non-null  int64
#  3   noise_type  50682 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.5+ MB

# %%
hackaton_df[['speaker', 'file']].groupby('speaker').count().sort_values(by="file")
# Out:
#          file
# speaker
# 87         11
# 3940       11
# 367        11
# 371        11
# 3679       11
# ...       ...
# 2565      621
# 709       637
# 3383      644
# 2343      646
# 3956      667
#
# [1016 rows x 1 columns]

# %%
hackaton_df[['speaker', 'file']].groupby('speaker').count().hist(bins=100)
# Out:
# array([[<Axes: title={'center': 'file'}>]], dtype=object)

# %%
hackaton_20_df = hackaton_df.groupby('speaker').head(20)

# %%
hackaton_20_df[['speaker', 'file']].groupby('speaker').count().plot(kind='bar')
# Out:
# <Axes: xlabel='speaker'>

# %%
challenge_df = pd.read_csv(DATA_DIR / 'hackathon_data' / 'groups_challenge.csv')

# %%
challenge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12314 entries, 0 to 12313
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   group_id          12314 non-null  int64
#  1   anchor_file       12314 non-null  object
#  2   anchor_type       12314 non-null  object
#  3   group_file        12314 non-null  object
#  4   group_audio_type  12314 non-null  object
#  5   anchor_language   12314 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 577.3+ KB

# %%
challenge_df['anchor_type'].value_counts()
# Out:
# anchor_type
# comm          6342
# background    5972
# Name: count, dtype: int64

# %%
hackaton_20_df['noise_type'].value_counts()
# Out:
# noise_type
# clean         10519
# background     4461
# comm           2541
# Name: count, dtype: int64

# %%
# Out:
#       language         file  speaker noise_type
# 0       arabic  2898082.wav     1571      clean
# 1       arabic  1996774.wav     1571      clean
# 2       arabic  2323175.wav     1571      clean
# 3       arabic  1083923.wav     1571      clean
# 4       arabic  5402632.wav      939      clean
# ...        ...          ...      ...        ...
# 50677  russian  1831230.wav     4227       comm
# 50678  russian  2113181.wav     4261       comm
# 50679  russian  5236583.wav     4261       comm
# 50680  russian  6795928.wav     4261       comm
# 50681  russian  1695262.wav     4261       comm
#
# [50682 rows x 4 columns]

# %%
hackaton_20_noise_df = hackaton_df[hackaton_df['noise_type'] != 'clean']

# %%
hackaton_20_noise_df['speaker'].value_counts()
# Out:
# speaker
# 3956    667
# 2343    646
# 3383    644
# 709     637
# 2565    621
#        ...
# 2286      7
# 4057      7
# 1638      7
# 1405      7
# 3940      7
# Name: count, Length: 1016, dtype: int64

# %%
hackaton_20_noise_df = hackaton_20_noise_df.groupby('speaker').head(20)

# %%
hackaton_20_noise_df['speaker'].value_counts()
# Out:
# speaker
# 4243    20
# 2908    20
# 3206    20
# 526     20
# 870     20
#         ..
# 1405     7
# 2274     7
# 2745     7
# 791      7
# 3589     7
# Name: count, Length: 1016, dtype: int64

# %%
hackaton_df['speaker'].value_counts()
# Out:
# speaker
# 3956    667
# 2343    646
# 3383    644
# 709     637
# 2565    621
#        ...
# 1921     11
# 3301     11
# 1609     11
# 1706     11
# 2441     11
# Name: count, Length: 1016, dtype: int64
